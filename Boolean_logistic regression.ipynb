# %%
import random
from math import exp, log

# %%
class logistic_regression_model():
    def __init__(self):
        self.w = [random.random(), random.random()]
        self.b = random.random()
    def sigmoid(self,z):
        return 1/(1 + exp(-z))
    def predict(self,x):
        z = self.w[0] * x[0] + self.w[1] * x[1] + self.b
        a = self.sigmoid(z)
        return a

# %%
model = logistic_regression_model()

# %%
def train(X, Y, model, lr = 0.1):
    dw0 = 0.0
    dw1 = 0.0
    db = 0.0
    m = len(X)
    cost = 0.0
    for x,y in zip(X,Y):
        a = model.predict(x)
        if y == 1:
            cost -= log(a)
        else:
            cost -= log(1-a)
        dw0 += (a-y)*x[0]
        dw1 += (a-y)*x[1]
        db += (a-y)
    cost /= m
    model.w[0] -= lr * dw0/m
    model.w[1] -= lr * dw1/m
    model.b -= lr*db/m

    return cost

# %%
X_AND = [(0,0), (1,0), (0,1), (1,1)]
Y_AND = [0, 0, 0, 1]
X_OR = [(0,0), (1,0), (0,1), (1,1)]
Y_OR = [0, 1, 1, 1]
X_XOR = [(0,0), (1,0), (0,1), (1,1)]
Y_XOR = [0, 1, 1, 0]

model_AND = logistic_regression_model()
model_OR = logistic_regression_model()
model_XOR = logistic_regression_model()

# %%
#학습률 0.1로 실행

# %%
for epoch in range(10000):
    cost_and = train(X_AND, Y_AND, model_AND, 0.1)
    cost_or = train(X_OR, Y_OR, model_OR, 0.1)
    cost_xor = train(X_XOR, Y_XOR, model_XOR, 0.1)
    if epoch % 100 == 0:
        print(f"Epoch {epoch} - AND Cost: {cost_and} | OR Cost: {cost_or} | XOR Cost: {cost_xor}")
# Out:
# Epoch 0 - AND Cost: 0.8297724916792988 | OR Cost: 0.46931750140329903 | XOR Cost: 0.8183554949126358
# Epoch 100 - AND Cost: 0.47929952753643296 | OR Cost: 0.3336326941982563 | XOR Cost: 0.6938309254179315
# Epoch 200 - AND Cost: 0.37300799719909217 | OR Cost: 0.2613117667716849 | XOR Cost: 0.6933762870748802
# Epoch 300 - AND Cost: 0.30823865118215593 | OR Cost: 0.21330710688455365 | XOR Cost: 0.6932337851843761
# Epoch 400 - AND Cost: 0.26412524466607795 | OR Cost: 0.17944918352675604 | XOR Cost: 0.6931815631902228
# Epoch 500 - AND Cost: 0.231743849735719 | OR Cost: 0.15439905262362372 | XOR Cost: 0.6931613965964168
# Epoch 600 - AND Cost: 0.20673756949317565 | OR Cost: 0.13517049514115648 | XOR Cost: 0.6931532438078551
# Epoch 700 - AND Cost: 0.1867247475357307 | OR Cost: 0.11998122530097324 | XOR Cost: 0.6931498248931088
# Epoch 800 - AND Cost: 0.170282566884063 | OR Cost: 0.10770452930666 | XOR Cost: 0.6931483515965661
# Epoch 900 - AND Cost: 0.1565005170517032 | OR Cost: 0.09759380723889066 | XOR Cost: 0.6931477044506271
# Epoch 1000 - AND Cost: 0.14476385353262933 | OR Cost: 0.08913508980822302 | XOR Cost: 0.6931474164907667
# Epoch 1100 - AND Cost: 0.13463958799362086 | OR Cost: 0.08196328985430903 | XOR Cost: 0.693147287262108
# Epoch 1200 - AND Cost: 0.12581223372333222 | OR Cost: 0.07581219601255224 | XOR Cost: 0.6931472289476652
# Epoch 1300 - AND Cost: 0.11804548634463063 | OR Cost: 0.07048332820468992 | XOR Cost: 0.6931472025405337
# Epoch 1400 - AND Cost: 0.11115826559194958 | OR Cost: 0.06582583966778295 | XOR Cost: 0.6931471905556006
# Epoch 1500 - AND Cost: 0.10500912802322285 | OR Cost: 0.06172314997434063 | XOR Cost: 0.6931471851085415
# Epoch 1600 - AND Cost: 0.0994857778621552 | OR Cost: 0.05808382071241505 | XOR Cost: 0.6931471826306977
# Epoch 1700 - AND Cost: 0.09449780206631828 | OR Cost: 0.05483518461740283 | XOR Cost: 0.693147181502909
# Epoch 1800 - AND Cost: 0.08997151209245502 | OR Cost: 0.05191880770114926 | XOR Cost: 0.6931471809894166
# Epoch 1900 - AND Cost: 0.08584620176483498 | OR Cost: 0.04928719923574847 | XOR Cost: 0.693147180755568
# Epoch 2000 - AND Cost: 0.08207138093839977 | OR Cost: 0.04690138829069896 | XOR Cost: 0.6931471806490566
# Epoch 2100 - AND Cost: 0.07860469637986196 | OR Cost: 0.04472911283493975 | XOR Cost: 0.6931471806005395
# Epoch 2200 - AND Cost: 0.07541034605811404 | OR Cost: 0.042743448861998705 | XOR Cost: 0.6931471805784382
# Epoch 2300 - AND Cost: 0.07245785382160948 | OR Cost: 0.04092176023136816 | XOR Cost: 0.6931471805683701
# Epoch 2400 - AND Cost: 0.06972111137050871 | OR Cost: 0.039244885393658356 | XOR Cost: 0.6931471805637834
# Epoch 2500 - AND Cost: 0.06717762122935006 | OR Cost: 0.03769650122430625 | XOR Cost: 0.693147180561694
# Epoch 2600 - AND Cost: 0.06480789276172115 | OR Cost: 0.03626262076794179 | XOR Cost: 0.6931471805607419
# Epoch 2700 - AND Cost: 0.06259495603552007 | OR Cost: 0.03493119328705697 | XOR Cost: 0.6931471805603083
# Epoch 2800 - AND Cost: 0.060523967379536636 | OR Cost: 0.033691783223878356 | XOR Cost: 0.6931471805601104
# Epoch 2900 - AND Cost: 0.058581886955120316 | OR Cost: 0.03253531057969845 | XOR Cost: 0.6931471805600207
# Epoch 3000 - AND Cost: 0.05675721338210734 | OR Cost: 0.03145383949566247 | XOR Cost: 0.6931471805599796
# Epoch 3100 - AND Cost: 0.05503976392983687 | OR Cost: 0.030440404959471548 | XOR Cost: 0.6931471805599609
# Epoch 3200 - AND Cost: 0.053420491368807284 | OR Cost: 0.029488869890184663 | XOR Cost: 0.6931471805599524
# Epoch 3300 - AND Cost: 0.05189133052285873 | OR Cost: 0.028593806594896982 | XOR Cost: 0.6931471805599485
# Epoch 3400 - AND Cost: 0.050445069038453624 | OR Cost: 0.02775039790565672 | XOR Cost: 0.6931471805599467
# Epoch 3500 - AND Cost: 0.04907523801912865 | OR Cost: 0.02695435430552896 | XOR Cost: 0.693147180559946
# Epoch 3600 - AND Cost: 0.04777601904740852 | OR Cost: 0.02620184412018732 | XOR Cost: 0.6931471805599456
# Epoch 3700 - AND Cost: 0.046542164797145506 | OR Cost: 0.025489434444487813 | XOR Cost: 0.6931471805599455
# Epoch 3800 - AND Cost: 0.04536893097306176 | OR Cost: 0.024814040934968612 | XOR Cost: 0.6931471805599454
# Epoch 3900 - AND Cost: 0.04425201773577589 | OR Cost: 0.02417288496071241 | XOR Cost: 0.6931471805599453
# Epoch 4000 - AND Cost: 0.04318751910553691 | OR Cost: 0.02356345688994504 | XOR Cost: 0.6931471805599453
# Epoch 4100 - AND Cost: 0.042171879105658866 | OR Cost: 0.02298348451567786 | XOR Cost: 0.6931471805599453
# Epoch 4200 - AND Cost: 0.04120185362193246 | OR Cost: 0.022430905803872078 | XOR Cost: 0.6931471805599453
# Epoch 4300 - AND Cost: 0.040274477128311836 | OR Cost: 0.021903845292050646 | XOR Cost: 0.6931471805599453
# Epoch 4400 - AND Cost: 0.03938703357055697 | OR Cost: 0.02140059358269483 | XOR Cost: 0.6931471805599453
# Epoch 4500 - AND Cost: 0.03853703081493931 | OR Cost: 0.020919589470033747 | XOR Cost: 0.6931471805599453
# Epoch 4600 - AND Cost: 0.03772217816378048 | OR Cost: 0.02045940431554149 | XOR Cost: 0.6931471805599453
# Epoch 4700 - AND Cost: 0.03694036651758083 | OR Cost: 0.02001872835015285 | XOR Cost: 0.6931471805599453
# Epoch 4800 - AND Cost: 0.03618965082799816 | OR Cost: 0.019596358632664887 | XOR Cost: 0.6931471805599453
# Epoch 4900 - AND Cost: 0.035468234539511694 | OR Cost: 0.01919118843621146 | XOR Cost: 0.6931471805599453
# Epoch 5000 - AND Cost: 0.03477445576227202 | OR Cost: 0.01880219786979591 | XOR Cost: 0.6931471805599453
# Epoch 5100 - AND Cost: 0.03410677495600606 | OR Cost: 0.01842844557101941 | XOR Cost: 0.6931471805599452
# Epoch 5200 - AND Cost: 0.03346376393622853 | OR Cost: 0.018069061330452583 | XOR Cost: 0.6931471805599454
# Epoch 5300 - AND Cost: 0.032844096040447364 | OR Cost: 0.017723239528427942 | XOR Cost: 0.6931471805599453
# Epoch 5400 - AND Cost: 0.03224653731439822 | OR Cost: 0.01739023328210495 | XOR Cost: 0.6931471805599453
# Epoch 5500 - AND Cost: 0.03166993859728121 | OR Cost: 0.017069349215030172 | XOR Cost: 0.6931471805599453
# Epoch 5600 - AND Cost: 0.03111322840109402 | OR Cost: 0.016759942773565056 | XOR Cost: 0.6931471805599453
# Epoch 5700 - AND Cost: 0.030575406492883754 | OR Cost: 0.016461414024841414 | XOR Cost: 0.6931471805599453
# Epoch 5800 - AND Cost: 0.030055538100497527 | OR Cost: 0.016173203879652983 | XOR Cost: 0.6931471805599453
# Epoch 5900 - AND Cost: 0.029552748672480252 | OR Cost: 0.015894790691144807 | XOR Cost: 0.6931471805599453
# Epoch 6000 - AND Cost: 0.029066219131434076 | OR Cost: 0.015625687186532736 | XOR Cost: 0.6931471805599452
# Epoch 6100 - AND Cost: 0.02859518156761476 | OR Cost: 0.015365437694542829 | XOR Cost: 0.6931471805599452
# Epoch 6200 - AND Cost: 0.028138915325989042 | OR Cost: 0.015113615635950166 | XOR Cost: 0.6931471805599453
# Epoch 6300 - AND Cost: 0.027696743445562298 | OR Cost: 0.014869821248632852 | XOR Cost: 0.6931471805599453
# Epoch 6400 - AND Cost: 0.027268029414630215 | OR Cost: 0.014633679522044533 | XOR Cost: 0.6931471805599453
# Epoch 6500 - AND Cost: 0.02685217420982171 | OR Cost: 0.014404838319020436 | XOR Cost: 0.6931471805599453
# Epoch 6600 - AND Cost: 0.026448613590477843 | OR Cost: 0.014182966665451357 | XOR Cost: 0.6931471805599452
# Epoch 6700 - AND Cost: 0.026056815623114543 | OR Cost: 0.01396775319062885 | XOR Cost: 0.6931471805599453
# Epoch 6800 - AND Cost: 0.025676278413528375 | OR Cost: 0.013758904703046002 | XOR Cost: 0.6931471805599454
# Epoch 6900 - AND Cost: 0.02530652802656623 | OR Cost: 0.013556144888162418 | XOR Cost: 0.6931471805599453
# Epoch 7000 - AND Cost: 0.024947116575739343 | OR Cost: 0.013359213116156145 | XOR Cost: 0.6931471805599452
# Epoch 7100 - AND Cost: 0.02459762046676974 | OR Cost: 0.013167863349004025 | XOR Cost: 0.6931471805599452
# Epoch 7200 - AND Cost: 0.024257638780830273 | OR Cost: 0.012981863137396278 | XOR Cost: 0.6931471805599452
# Epoch 7300 - AND Cost: 0.023926791784726405 | OR Cost: 0.012800992699008227 | XOR Cost: 0.6931471805599453
# Epoch 7400 - AND Cost: 0.023604719556572708 | OR Cost: 0.012625044070557463 | XOR Cost: 0.6931471805599453
# Epoch 7500 - AND Cost: 0.0232910807166852 | OR Cost: 0.012453820326861686 | XOR Cost: 0.6931471805599452
# Epoch 7600 - AND Cost: 0.022985551254434126 | OR Cost: 0.01228713486081876 | XOR Cost: 0.6931471805599453
# Epoch 7700 - AND Cost: 0.022687823442725207 | OR Cost: 0.012124810718849724 | XOR Cost: 0.6931471805599453
# Epoch 7800 - AND Cost: 0.022397604832586307 | OR Cost: 0.011966679986895816 | XOR Cost: 0.6931471805599453
# Epoch 7900 - AND Cost: 0.0221146173210678 | OR Cost: 0.01181258322255102 | XOR Cost: 0.6931471805599453
# Epoch 8000 - AND Cost: 0.021838596286312725 | OR Cost: 0.011662368929345987 | XOR Cost: 0.6931471805599453
# Epoch 8100 - AND Cost: 0.021569289784231706 | OR Cost: 0.011515893069586463 | XOR Cost: 0.6931471805599452
# Epoch 8200 - AND Cost: 0.021306457801738822 | OR Cost: 0.011373018612495213 | XOR Cost: 0.6931471805599452
# Epoch 8300 - AND Cost: 0.02104987156196941 | OR Cost: 0.011233615114716062 | XOR Cost: 0.6931471805599452
# Epoch 8400 - AND Cost: 0.020799312877318607 | OR Cost: 0.011097558330514248 | XOR Cost: 0.6931471805599452
# Epoch 8500 - AND Cost: 0.020554573546513834 | OR Cost: 0.01096472984925517 | XOR Cost: 0.6931471805599453
# Epoch 8600 - AND Cost: 0.02031545479227599 | OR Cost: 0.010835016757963958 | XOR Cost: 0.6931471805599453
# Epoch 8700 - AND Cost: 0.020081766736423333 | OR Cost: 0.01070831132697176 | XOR Cost: 0.6931471805599453
# Epoch 8800 - AND Cost: 0.019853327909551244 | OR Cost: 0.010584510716828555 | XOR Cost: 0.6931471805599453
# Epoch 8900 - AND Cost: 0.019629964792665603 | OR Cost: 0.010463516704827255 | XOR Cost: 0.6931471805599453
# Epoch 9000 - AND Cost: 0.01941151138837413 | OR Cost: 0.010345235429630015 | XOR Cost: 0.6931471805599453
# Epoch 9100 - AND Cost: 0.019197808819441144 | OR Cost: 0.010229577152614596 | XOR Cost: 0.6931471805599453
# Epoch 9200 - AND Cost: 0.018988704952695425 | OR Cost: 0.0101164560346822 | XOR Cost: 0.6931471805599453
# Epoch 9300 - AND Cost: 0.018784054046447982 | OR Cost: 0.010005789927372085 | XOR Cost: 0.6931471805599453
# Epoch 9400 - AND Cost: 0.018583716419727617 | OR Cost: 0.009897500177227526 | XOR Cost: 0.6931471805599453
# Epoch 9500 - AND Cost: 0.018387558141778573 | OR Cost: 0.00979151144244412 | XOR Cost: 0.6931471805599453
# Epoch 9600 - AND Cost: 0.018195450740392135 | OR Cost: 0.00968775152091165 | XOR Cost: 0.6931471805599453
# Epoch 9700 - AND Cost: 0.018007270927754546 | OR Cost: 0.009586151188835513 | XOR Cost: 0.6931471805599453
# Epoch 9800 - AND Cost: 0.01782290034260091 | OR Cost: 0.009486644049184647 | XOR Cost: 0.6931471805599453
# Epoch 9900 - AND Cost: 0.01764222530755645 | OR Cost: 0.009389166389279436 | XOR Cost: 0.6931471805599453

# %%
print("AND Prediction (0, 0):", model_AND.predict((0, 0)))
print("AND Prediction (0, 1):", model_AND.predict((0, 1)))
print("AND Prediction (1, 0):", model_AND.predict((1, 0)))
print("AND Prediction (1, 1):", model_AND.predict((1, 1)))

print("OR Prediction (0, 0):", model_OR.predict((0, 0)))
print("OR Prediction (0, 1):", model_OR.predict((0, 1)))
print("OR Prediction (1, 0):", model_OR.predict((1, 0)))
print("OR Prediction (1, 1):", model_OR.predict((1, 1)))

print("XOR Prediction (0, 0):", model_XOR.predict((0, 0)))
print("XOR Prediction (0, 1):", model_XOR.predict((0, 1)))
print("XOR Prediction (1, 0):", model_XOR.predict((1, 0)))
print("XOR Prediction (1, 1):", model_XOR.predict((1, 1)))
# Out:
# AND Prediction (0, 0): 1.255664060273196e-05
# AND Prediction (0, 1): 0.020295948413787998
# AND Prediction (1, 0): 0.02029594732692133
# AND Prediction (1, 1): 0.9715733525512229
# OR Prediction (0, 0): 0.02050968765806193
# OR Prediction (0, 1): 0.9918063408975073
# OR Prediction (1, 0): 0.9918108590011099
# OR Prediction (1, 1): 0.9999985717021523
# XOR Prediction (0, 0): 0.5
# XOR Prediction (0, 1): 0.5
# XOR Prediction (1, 0): 0.5
# XOR Prediction (1, 1): 0.5

# %%
#학습률 0.3로 실행

# %%
for epoch in range(10000):
    cost_and = train(X_AND, Y_AND, model_AND, 0.3)
    cost_or = train(X_OR, Y_OR, model_OR, 0.3)
    cost_xor = train(X_XOR, Y_XOR, model_XOR, 0.3)
    if epoch % 100 == 0:
        print(f"Epoch {epoch} - AND Cost: {cost_and} | OR Cost: {cost_or} | XOR Cost: {cost_xor}")
# Out:
# Epoch 0 - AND Cost: 0.017465136600635367 | OR Cost: 0.009293657046882562 | XOR Cost: 0.6931471805599453
# Epoch 100 - AND Cost: 0.016954310080049738 | OR Cost: 0.009018336372792556 | XOR Cost: 0.6931471805599453
# Epoch 200 - AND Cost: 0.016472220015723196 | OR Cost: 0.00875875220308161 | XOR Cost: 0.6931471805599453
# Epoch 300 - AND Cost: 0.016016522984006076 | OR Cost: 0.008513598498931173 | XOR Cost: 0.6931471805599453
# Epoch 400 - AND Cost: 0.01558512250266749 | OR Cost: 0.008281709418384537 | XOR Cost: 0.6931471805599453
# Epoch 500 - AND Cost: 0.015176137446246695 | OR Cost: 0.008062041040128825 | XOR Cost: 0.6931471805599453
# Epoch 600 - AND Cost: 0.014787875175663082 | OR Cost: 0.007853655868264134 | XOR Cost: 0.6931471805599453
# Epoch 700 - AND Cost: 0.0144188085828067 | OR Cost: 0.007655709637345168 | XOR Cost: 0.6931471805599453
# Epoch 800 - AND Cost: 0.014067556401777447 | OR Cost: 0.007467440029532897 | XOR Cost: 0.6931471805599453
# Epoch 900 - AND Cost: 0.013732866258102217 | OR Cost: 0.007288156988692607 | XOR Cost: 0.6931471805599453
# Epoch 1000 - AND Cost: 0.01341360002266967 | OR Cost: 0.0071172343742036135 | XOR Cost: 0.6931471805599453
# Epoch 1100 - AND Cost: 0.013108721113612977 | OR Cost: 0.006954102743472782 | XOR Cost: 0.6931471805599453
# Epoch 1200 - AND Cost: 0.012817283451023766 | OR Cost: 0.006798243089248192 | XOR Cost: 0.6931471805599453
# Epoch 1300 - AND Cost: 0.012538421819310093 | OR Cost: 0.006649181387751218 | XOR Cost: 0.6931471805599453
# Epoch 1400 - AND Cost: 0.012271343432653407 | OR Cost: 0.006506483837909575 | XOR Cost: 0.6931471805599453
# Epoch 1500 - AND Cost: 0.012015320532242961 | OR Cost: 0.006369752691733496 | XOR Cost: 0.6931471805599453
# Epoch 1600 - AND Cost: 0.011769683871248687 | OR Cost: 0.0062386225920458855 | XOR Cost: 0.6931471805599453
# Epoch 1700 - AND Cost: 0.011533816965990182 | OR Cost: 0.006112757347069096 | XOR Cost: 0.6931471805599453
# Epoch 1800 - AND Cost: 0.011307151010383806 | OR Cost: 0.0059918470823322025 | XOR Cost: 0.6931471805599453
# Epoch 1900 - AND Cost: 0.011089160366228043 | OR Cost: 0.005875605719450492 | XOR Cost: 0.6931471805599453
# Epoch 2000 - AND Cost: 0.010879358554798064 | OR Cost: 0.005763768738885232 | XOR Cost: 0.6931471805599453
# Epoch 2100 - AND Cost: 0.0106772946860296 | OR Cost: 0.005656091190097514 | XOR Cost: 0.6931471805599453
# Epoch 2200 - AND Cost: 0.010482550270648648 | OR Cost: 0.005552345917795285 | XOR Cost: 0.6931471805599453
# Epoch 2300 - AND Cost: 0.01029473636825461 | OR Cost: 0.005452321977413449 | XOR Cost: 0.6931471805599453
# Epoch 2400 - AND Cost: 0.010113491030833734 | OR Cost: 0.005355823216711718 | XOR Cost: 0.6931471805599453
# Epoch 2500 - AND Cost: 0.009938477006660352 | OR Cost: 0.00526266700354441 | XOR Cost: 0.6931471805599453
# Epoch 2600 - AND Cost: 0.009769379674211662 | OR Cost: 0.005172683082543833 | XOR Cost: 0.6931471805599453
# Epoch 2700 - AND Cost: 0.009605905179697088 | OR Cost: 0.005085712545746617 | XOR Cost: 0.6931471805599453
# Epoch 2800 - AND Cost: 0.009447778755205747 | OR Cost: 0.005001606904145986 | XOR Cost: 0.6931471805599453
# Epoch 2900 - AND Cost: 0.009294743197394012 | OR Cost: 0.004920227248823419 | XOR Cost: 0.6931471805599453
# Epoch 3000 - AND Cost: 0.00914655748914111 | OR Cost: 0.004841443491745319 | XOR Cost: 0.6931471805599453
# Epoch 3100 - AND Cost: 0.009002995548763703 | OR Cost: 0.004765133677545159 | XOR Cost: 0.6931471805599453
# Epoch 3200 - AND Cost: 0.008863845093245714 | OR Cost: 0.004691183358675133 | XOR Cost: 0.6931471805599453
# Epoch 3300 - AND Cost: 0.008728906603558474 | OR Cost: 0.004619485027228445 | XOR Cost: 0.6931471805599453
# Epoch 3400 - AND Cost: 0.008597992381546292 | OR Cost: 0.004549937597531259 | XOR Cost: 0.6931471805599453
# Epoch 3500 - AND Cost: 0.008470925689075922 | OR Cost: 0.004482445934295362 | XOR Cost: 0.6931471805599453
# Epoch 3600 - AND Cost: 0.0083475399612098 | OR Cost: 0.004416920421721827 | XOR Cost: 0.6931471805599453
# Epoch 3700 - AND Cost: 0.008227678086091521 | OR Cost: 0.004353276569473149 | XOR Cost: 0.6931471805599453
# Epoch 3800 - AND Cost: 0.008111191745046398 | OR Cost: 0.004291434651888422 | XOR Cost: 0.6931471805599453
# Epoch 3900 - AND Cost: 0.007997940807111543 | OR Cost: 0.004231319377217764 | XOR Cost: 0.6931471805599453
# Epoch 4000 - AND Cost: 0.007887792772835033 | OR Cost: 0.004172859584004711 | XOR Cost: 0.6931471805599453
# Epoch 4100 - AND Cost: 0.0077806222627360075 | OR Cost: 0.0041159879620539476 | XOR Cost: 0.6931471805599453
# Epoch 4200 - AND Cost: 0.007676310546303338 | OR Cost: 0.004060640795695434 | XOR Cost: 0.6931471805599453
# Epoch 4300 - AND Cost: 0.0075747451078373735 | OR Cost: 0.004006757727294579 | XOR Cost: 0.6931471805599453
# Epoch 4400 - AND Cost: 0.007475819245820721 | OR Cost: 0.0039542815391723635 | XOR Cost: 0.6931471805599453
# Epoch 4500 - AND Cost: 0.007379431702839058 | OR Cost: 0.0039031579522859966 | XOR Cost: 0.6931471805599453
# Epoch 4600 - AND Cost: 0.007285486323372175 | OR Cost: 0.0038533354401871648 | XOR Cost: 0.6931471805599453
# Epoch 4700 - AND Cost: 0.007193891737039083 | OR Cost: 0.00380476505692382 | XOR Cost: 0.6931471805599453
# Epoch 4800 - AND Cost: 0.007104561065118948 | OR Cost: 0.0037574002776815307 | XOR Cost: 0.6931471805599453
# Epoch 4900 - AND Cost: 0.00701741164837855 | OR Cost: 0.003711196851080292 | XOR Cost: 0.6931471805599453
# Epoch 5000 - AND Cost: 0.00693236479442482 | OR Cost: 0.003666112662142186 | XOR Cost: 0.6931471805599453
# Epoch 5100 - AND Cost: 0.006849345542971296 | OR Cost: 0.003622107605044593 | XOR Cost: 0.6931471805599453
# Epoch 5200 - AND Cost: 0.006768282447553555 | OR Cost: 0.0035791434648521346 | XOR Cost: 0.6931471805599453
# Epoch 5300 - AND Cost: 0.006689107372367106 | OR Cost: 0.003537183807498573 | XOR Cost: 0.6931471805599453
# Epoch 5400 - AND Cost: 0.0066117553030210965 | OR Cost: 0.0034961938773541263 | XOR Cost: 0.6931471805599453
# Epoch 5500 - AND Cost: 0.00653616417010866 | OR Cost: 0.0034561405017772525 | XOR Cost: 0.6931471805599453
# Epoch 5600 - AND Cost: 0.006462274684594739 | OR Cost: 0.0034169920020999884 | XOR Cost: 0.6931471805599453
# Epoch 5700 - AND Cost: 0.006390030184107516 | OR Cost: 0.003378718110548517 | XOR Cost: 0.6931471805599453
# Epoch 5800 - AND Cost: 0.006319376489303521 | OR Cost: 0.0033412898926420296 | XOR Cost: 0.6931471805599453
# Epoch 5900 - AND Cost: 0.006250261769542698 | OR Cost: 0.003304679674652427 | XOR Cost: 0.6931471805599453
# Epoch 6000 - AND Cost: 0.0061826364171792955 | OR Cost: 0.0032688609757464447 | XOR Cost: 0.6931471805599453
# Epoch 6100 - AND Cost: 0.006116452929831153 | OR Cost: 0.003233808444459197 | XOR Cost: 0.6931471805599453
# Epoch 6200 - AND Cost: 0.006051665800042662 | OR Cost: 0.0031994977991816696 | XOR Cost: 0.6931471805599453
# Epoch 6300 - AND Cost: 0.005988231411807118 | OR Cost: 0.003165905772369122 | XOR Cost: 0.6931471805599453
# Epoch 6400 - AND Cost: 0.005926107943455373 | OR Cost: 0.003133010058202241 | XOR Cost: 0.6931471805599453
# Epoch 6500 - AND Cost: 0.005865255276459633 | OR Cost: 0.0031007892634534293 | XOR Cost: 0.6931471805599453
# Epoch 6600 - AND Cost: 0.005805634909736371 | OR Cost: 0.003069222861333419 | XOR Cost: 0.6931471805599453
# Epoch 6700 - AND Cost: 0.005747209879066342 | OR Cost: 0.003038291148108042 | XOR Cost: 0.6931471805599453
# Epoch 6800 - AND Cost: 0.005689944681278309 | OR Cost: 0.0030079752022939164 | XOR Cost: 0.6931471805599453
# Epoch 6900 - AND Cost: 0.005633805202871605 | OR Cost: 0.002978256846256469 | XOR Cost: 0.6931471805599453
# Epoch 7000 - AND Cost: 0.005578758652778369 | OR Cost: 0.002949118610045417 | XOR Cost: 0.6931471805599453
# Epoch 7100 - AND Cost: 0.005524773498987229 | OR Cost: 0.0029205436973194308 | XOR Cost: 0.6931471805599453
# Epoch 7200 - AND Cost: 0.005471819408773036 | OR Cost: 0.002892515953218634 | XOR Cost: 0.6931471805599453
# Epoch 7300 - AND Cost: 0.005419867192295807 | OR Cost: 0.002865019834057441 | XOR Cost: 0.6931471805599453
# Epoch 7400 - AND Cost: 0.0053688887493488074 | OR Cost: 0.002838040378718381 | XOR Cost: 0.6931471805599453
# Epoch 7500 - AND Cost: 0.005318857019054132 | OR Cost: 0.002811563181636384 | XOR Cost: 0.6931471805599453
# Epoch 7600 - AND Cost: 0.005269745932315789 | OR Cost: 0.002785574367271641 | XOR Cost: 0.6931471805599453
# Epoch 7700 - AND Cost: 0.005221530366856887 | OR Cost: 0.002760060565975998 | XOR Cost: 0.6931471805599453
# Epoch 7800 - AND Cost: 0.005174186104678137 | OR Cost: 0.0027350088911655 | XOR Cost: 0.6931471805599453
# Epoch 7900 - AND Cost: 0.005127689791787121 | OR Cost: 0.002710406917716873 | XOR Cost: 0.6931471805599453
# Epoch 8000 - AND Cost: 0.005082018900058173 | OR Cost: 0.002686242661512205 | XOR Cost: 0.6931471805599453
# Epoch 8100 - AND Cost: 0.005037151691093483 | OR Cost: 0.002662504560061598 | XOR Cost: 0.6931471805599453
# Epoch 8200 - AND Cost: 0.004993067181962012 | OR Cost: 0.0026391814541377907 | XOR Cost: 0.6931471805599453
# Epoch 8300 - AND Cost: 0.004949745112706834 | OR Cost: 0.002616262570361799 | XOR Cost: 0.6931471805599453
# Epoch 8400 - AND Cost: 0.0049071659155112595 | OR Cost: 0.0025937375046828225 | XOR Cost: 0.6931471805599453
# Epoch 8500 - AND Cost: 0.0048653106854296335 | OR Cost: 0.0025715962066987503 | XOR Cost: 0.6931471805599453
# Epoch 8600 - AND Cost: 0.004824161152589082 | OR Cost: 0.0025498289647688023 | XOR Cost: 0.6931471805599453
# Epoch 8700 - AND Cost: 0.004783699655776141 | OR Cost: 0.0025284263918707276 | XOR Cost: 0.6931471805599453
# Epoch 8800 - AND Cost: 0.00474390911733098 | OR Cost: 0.002507379412160862 | XOR Cost: 0.6931471805599453
# Epoch 8900 - AND Cost: 0.004704773019271754 | OR Cost: 0.002486679248195513 | XOR Cost: 0.6931471805599453
# Epoch 9000 - AND Cost: 0.004666275380580737 | OR Cost: 0.002466317408777015 | XOR Cost: 0.6931471805599453
# Epoch 9100 - AND Cost: 0.004628400735587176 | OR Cost: 0.00244628567738797 | XOR Cost: 0.6931471805599453
# Epoch 9200 - AND Cost: 0.004591134113384224 | OR Cost: 0.002426576101182055 | XOR Cost: 0.6931471805599453
# Epoch 9300 - AND Cost: 0.004554461018224624 | OR Cost: 0.002407180980499586 | XOR Cost: 0.6931471805599453
# Epoch 9400 - AND Cost: 0.00451836741083916 | OR Cost: 0.002388092858878674 | XOR Cost: 0.6931471805599453
# Epoch 9500 - AND Cost: 0.004482839690629703 | OR Cost: 0.0023693045135362483 | XOR Cost: 0.6931471805599453
# Epoch 9600 - AND Cost: 0.004447864678688456 | OR Cost: 0.0023508089462913047 | XOR Cost: 0.6931471805599453
# Epoch 9700 - AND Cost: 0.004413429601598566 | OR Cost: 0.002332599374908637 | XOR Cost: 0.6931471805599453
# Epoch 9800 - AND Cost: 0.004379522075975833 | OR Cost: 0.002314669224839049 | XOR Cost: 0.6931471805599453
# Epoch 9900 - AND Cost: 0.004346130093711098 | OR Cost: 0.002297012121335635 | XOR Cost: 0.6931471805599453

# %%
print("AND Prediction (0, 0):", model_AND.predict((0, 0)))
print("AND Prediction (0, 1):", model_AND.predict((0, 1)))
print("AND Prediction (1, 0):", model_AND.predict((1, 0)))
print("AND Prediction (1, 1):", model_AND.predict((1, 1)))

print("OR Prediction (0, 0):", model_OR.predict((0, 0)))
print("OR Prediction (0, 1):", model_OR.predict((0, 1)))
print("OR Prediction (1, 0):", model_OR.predict((1, 0)))
print("OR Prediction (1, 1):", model_OR.predict((1, 1)))

print("XOR Prediction (0, 0):", model_XOR.predict((0, 0)))
print("XOR Prediction (0, 1):", model_XOR.predict((0, 1)))
print("XOR Prediction (1, 0):", model_XOR.predict((1, 0)))
print("XOR Prediction (1, 1):", model_XOR.predict((1, 1)))
# Out:
# AND Prediction (0, 0): 1.8446143297047927e-07
# AND Prediction (0, 1): 0.0050592328691503536
# AND Prediction (1, 0): 0.005059232868889456
# AND Prediction (1, 1): 0.9929165712489715
# OR Prediction (0, 0): 0.005057189830101888
# OR Prediction (0, 1): 0.9979777905459731
# OR Prediction (1, 0): 0.997977858202537
# OR Prediction (1, 1): 0.9999999791307381
# XOR Prediction (0, 0): 0.5
# XOR Prediction (0, 1): 0.5
# XOR Prediction (1, 0): 0.5
# XOR Prediction (1, 1): 0.5

# %%
#학습률 0.7로 실행

# %%
for epoch in range(10000):
    cost_and = train(X_AND, Y_AND, model_AND, 0.7)
    cost_or = train(X_OR, Y_OR, model_OR, 0.7)
    cost_xor = train(X_XOR, Y_XOR, model_XOR, 0.7)
    if epoch % 100 == 0:
        print(f"Epoch {epoch} - AND Cost: {cost_and} | OR Cost: {cost_or} | XOR Cost: {cost_xor}")
# Out:
# Epoch 0 - AND Cost: 0.004313242007877477 | OR Cost: 0.0022796218819267243 | XOR Cost: 0.6931471805599453
# Epoch 100 - AND Cost: 0.004238396224675878 | OR Cost: 0.0022400471629459386 | XOR Cost: 0.6931471805599453
# Epoch 200 - AND Cost: 0.00416609671936688 | OR Cost: 0.0022018207337524496 | XOR Cost: 0.6931471805599453
# Epoch 300 - AND Cost: 0.004096215952703679 | OR Cost: 0.0021648749206566575 | XOR Cost: 0.6931471805599453
# Epoch 400 - AND Cost: 0.004028634752453463 | OR Cost: 0.0021291465007343326 | XOR Cost: 0.6931471805599453
# Epoch 500 - AND Cost: 0.003963241639014057 | OR Cost: 0.0020945763420774626 | XOR Cost: 0.6931471805599453
# Epoch 600 - AND Cost: 0.003899932215169913 | OR Cost: 0.002061109078365602 | XOR Cost: 0.6931471805599453
# Epoch 700 - AND Cost: 0.0038386086129866244 | OR Cost: 0.0020286928139993383 | XOR Cost: 0.6931471805599453
# Epoch 800 - AND Cost: 0.0037791789917025562 | OR Cost: 0.0019972788565009534 | XOR Cost: 0.6931471805599453
# Epoch 900 - AND Cost: 0.003721557081218023 | OR Cost: 0.0019668214732849803 | XOR Cost: 0.6931471805599453
# Epoch 1000 - AND Cost: 0.00366566176642652 | OR Cost: 0.0019372776702512578 | XOR Cost: 0.6931471805599453
# Epoch 1100 - AND Cost: 0.003611416708190341 | OR Cost: 0.0019086069899480155 | XOR Cost: 0.6931471805599453
# Epoch 1200 - AND Cost: 0.0035587499972486213 | OR Cost: 0.0018807713273209156 | XOR Cost: 0.6931471805599453
# Epoch 1300 - AND Cost: 0.003507593837768896 | OR Cost: 0.0018537347612823329 | XOR Cost: 0.6931471805599453
# Epoch 1400 - AND Cost: 0.0034578842576241564 | OR Cost: 0.0018274634005424433 | XOR Cost: 0.6931471805599453
# Epoch 1500 - AND Cost: 0.00340956084279941 | OR Cost: 0.0018019252423121213 | XOR Cost: 0.6931471805599453
# Epoch 1600 - AND Cost: 0.003362566493617201 | OR Cost: 0.001777090042640876 | XOR Cost: 0.6931471805599453
# Epoch 1700 - AND Cost: 0.003316847200720529 | OR Cost: 0.0017529291972893395 | XOR Cost: 0.6931471805599453
# Epoch 1800 - AND Cost: 0.0032723518389704033 | OR Cost: 0.0017294156321493157 | XOR Cost: 0.6931471805599453
# Epoch 1900 - AND Cost: 0.003229031977609752 | OR Cost: 0.001706523702332882 | XOR Cost: 0.6931471805599453
# Epoch 2000 - AND Cost: 0.003186841705216912 | OR Cost: 0.0016842290991397238 | XOR Cost: 0.6931471805599453
# Epoch 2100 - AND Cost: 0.0031457374681209903 | OR Cost: 0.0016625087641948617 | XOR Cost: 0.6931471805599453
# Epoch 2200 - AND Cost: 0.0031056779210887936 | OR Cost: 0.0016413408101204863 | XOR Cost: 0.6931471805599453
# Epoch 2300 - AND Cost: 0.0030666237892090402 | OR Cost: 0.0016207044471701695 | XOR Cost: 0.6931471805599453
# Epoch 2400 - AND Cost: 0.0030285377400075366 | OR Cost: 0.0016005799153073277 | XOR Cost: 0.6931471805599453
# Epoch 2500 - AND Cost: 0.0029913842649199798 | OR Cost: 0.0015809484212642394 | XOR Cost: 0.6931471805599453
# Epoch 2600 - AND Cost: 0.0029551295693336773 | OR Cost: 0.0015617920801597783 | XOR Cost: 0.6931471805599453
# Epoch 2700 - AND Cost: 0.0029197414704849756 | OR Cost: 0.0015430938612968435 | XOR Cost: 0.6931471805599453
# Epoch 2800 - AND Cost: 0.0028851893025644386 | OR Cost: 0.0015248375377920108 | XOR Cost: 0.6931471805599453
# Epoch 2900 - AND Cost: 0.002851443828444625 | OR Cost: 0.0015070076397276607 | XOR Cost: 0.6931471805599453
# Epoch 3000 - AND Cost: 0.0028184771574972234 | OR Cost: 0.0014895894105416497 | XOR Cost: 0.6931471805599453
# Epoch 3100 - AND Cost: 0.0027862626690149713 | OR Cost: 0.001472568766395757 | XOR Cost: 0.6931471805599453
# Epoch 3200 - AND Cost: 0.0027547749407981588 | OR Cost: 0.001455932258289983 | XOR Cost: 0.6931471805599453
# Epoch 3300 - AND Cost: 0.0027239896825040025 | OR Cost: 0.001439667036706527 | XOR Cost: 0.6931471805599453
# Epoch 3400 - AND Cost: 0.002693883673391715 | OR Cost: 0.0014237608185909076 | XOR Cost: 0.6931471805599453
# Epoch 3500 - AND Cost: 0.002664434704130596 | OR Cost: 0.001408201856490154 | XOR Cost: 0.6931471805599453
# Epoch 3600 - AND Cost: 0.0026356215223633595 | OR Cost: 0.00139297890968681 | XOR Cost: 0.6931471805599453
# Epoch 3700 - AND Cost: 0.0026074237817462513 | OR Cost: 0.001378081217178572 | XOR Cost: 0.6931471805599453
# Epoch 3800 - AND Cost: 0.002579821994209884 | OR Cost: 0.0013634984723683904 | XOR Cost: 0.6931471805599453
# Epoch 3900 - AND Cost: 0.0025527974852047946 | OR Cost: 0.0013492207993401543 | XOR Cost: 0.6931471805599453
# Epoch 4000 - AND Cost: 0.0025263323517175284 | OR Cost: 0.0013352387306037857 | XOR Cost: 0.6931471805599453
# Epoch 4100 - AND Cost: 0.0025004094228586815 | OR Cost: 0.0013215431862069202 | XOR Cost: 0.6931471805599453
# Epoch 4200 - AND Cost: 0.0024750122228411747 | OR Cost: 0.0013081254541142738 | XOR Cost: 0.6931471805599453
# Epoch 4300 - AND Cost: 0.0024501249361813275 | OR Cost: 0.0012949771717672143 | XOR Cost: 0.6931471805599453
# Epoch 4400 - AND Cost: 0.0024257323749687174 | OR Cost: 0.001282090308740806 | XOR Cost: 0.6931471805599453
# Epoch 4500 - AND Cost: 0.0024018199480627268 | OR Cost: 0.0012694571504235437 | XOR Cost: 0.6931471805599453
# Epoch 4600 - AND Cost: 0.002378373632085098 | OR Cost: 0.001257070282648936 | XOR Cost: 0.6931471805599453
# Epoch 4700 - AND Cost: 0.002355379944087076 | OR Cost: 0.0012449225772165834 | XOR Cost: 0.6931471805599453
# Epoch 4800 - AND Cost: 0.0023328259157797252 | OR Cost: 0.001233007178241669 | XOR Cost: 0.6931471805599453
# Epoch 4900 - AND Cost: 0.002310699069224225 | OR Cost: 0.0012213174892790057 | XOR Cost: 0.6931471805599453
# Epoch 5000 - AND Cost: 0.0022889873938865928 | OR Cost: 0.0012098471611702649 | XOR Cost: 0.6931471805599453
# Epoch 5100 - AND Cost: 0.0022676793249682115 | OR Cost: 0.0011985900805681277 | XOR Cost: 0.6931471805599453
# Epoch 5200 - AND Cost: 0.0022467637229298975 | OR Cost: 0.001187540359093658 | XOR Cost: 0.6931471805599453
# Epoch 5300 - AND Cost: 0.002226229854134621 | OR Cost: 0.0011766923230854087 | XOR Cost: 0.6931471805599453
# Epoch 5400 - AND Cost: 0.0022060673725368706 | OR Cost: 0.0011660405039046959 | XOR Cost: 0.6931471805599453
# Epoch 5500 - AND Cost: 0.0021862663023540585 | OR Cost: 0.001155579628761018 | XOR Cost: 0.6931471805599453
# Epoch 5600 - AND Cost: 0.002166817021659248 | OR Cost: 0.0011453046120251192 | XOR Cost: 0.6931471805599453
# Epoch 5700 - AND Cost: 0.0021477102468380003 | OR Cost: 0.0011352105470015146 | XOR Cost: 0.6931471805599453
# Epoch 5800 - AND Cost: 0.0021289370178568874 | OR Cost: 0.001125292698129101 | XOR Cost: 0.6931471805599453
# Epoch 5900 - AND Cost: 0.002110488684295066 | OR Cost: 0.0011155464935884765 | XOR Cost: 0.6931471805599453
# Epoch 6000 - AND Cost: 0.0020923568920928315 | OR Cost: 0.0011059675182869242 | XOR Cost: 0.6931471805599453
# Epoch 6100 - AND Cost: 0.0020745335709744252 | OR Cost: 0.001096551507202406 | XOR Cost: 0.6931471805599453
# Epoch 6200 - AND Cost: 0.0020570109225062096 | OR Cost: 0.0010872943390628246 | XOR Cost: 0.6931471805599453
# Epoch 6300 - AND Cost: 0.0020397814087519256 | OR Cost: 0.0010781920303428365 | XOR Cost: 0.6931471805599453
# Epoch 6400 - AND Cost: 0.002022837741491669 | OR Cost: 0.001069240729557854 | XOR Cost: 0.6931471805599453
# Epoch 6500 - AND Cost: 0.00200617287197149 | OR Cost: 0.00106043671184068 | XOR Cost: 0.6931471805599453
# Epoch 6600 - AND Cost: 0.0019897799811534967 | OR Cost: 0.001051776373781676 | XOR Cost: 0.6931471805599453
# Epoch 6700 - AND Cost: 0.0019736524704382506 | OR Cost: 0.001043256228520564 | XOR Cost: 0.6931471805599453
# Epoch 6800 - AND Cost: 0.001957783952833214 | OR Cost: 0.0010348729010729164 | XOR Cost: 0.6931471805599453
# Epoch 6900 - AND Cost: 0.0019421682445420775 | OR Cost: 0.001026623123881334 | XOR Cost: 0.6931471805599453
# Epoch 7000 - AND Cost: 0.0019267993569518447 | OR Cost: 0.0010185037325749066 | XOR Cost: 0.6931471805599453
# Epoch 7100 - AND Cost: 0.0019116714889962365 | OR Cost: 0.0010105116619306112 | XOR Cost: 0.6931471805599453
# Epoch 7200 - AND Cost: 0.001896779019874405 | OR Cost: 0.0010026439420204381 | XOR Cost: 0.6931471805599453
# Epoch 7300 - AND Cost: 0.0018821165021063238 | OR Cost: 0.0009948976945384417 | XOR Cost: 0.6931471805599453
# Epoch 7400 - AND Cost: 0.0018676786549064594 | OR Cost: 0.0009872701292953534 | XOR Cost: 0.6931471805599453
# Epoch 7500 - AND Cost: 0.0018534603578593924 | OR Cost: 0.0009797585408732007 | XOR Cost: 0.6931471805599453
# Epoch 7600 - AND Cost: 0.0018394566448803194 | OR Cost: 0.0009723603054315571 | XOR Cost: 0.6931471805599453
# Epoch 7700 - AND Cost: 0.0018256626984475455 | OR Cost: 0.0009650728776560408 | XOR Cost: 0.6931471805599453
# Epoch 7800 - AND Cost: 0.001812073844090305 | OR Cost: 0.0009578937878439355 | XOR Cost: 0.6931471805599453
# Epoch 7900 - AND Cost: 0.0017986855451211214 | OR Cost: 0.0009508206391176222 | XOR Cost: 0.6931471805599453
# Epoch 8000 - AND Cost: 0.0017854933975983709 | OR Cost: 0.0009438511047610021 | XOR Cost: 0.6931471805599453
# Epoch 8100 - AND Cost: 0.0017724931255086302 | OR Cost: 0.0009369829256714068 | XOR Cost: 0.6931471805599453
# Epoch 8200 - AND Cost: 0.001759680576157465 | OR Cost: 0.0009302139079224079 | XOR Cost: 0.6931471805599453
# Epoch 8300 - AND Cost: 0.0017470517157572292 | OR Cost: 0.0009235419204303582 | XOR Cost: 0.6931471805599453
# Epoch 8400 - AND Cost: 0.001734602625203504 | OR Cost: 0.0009169648927214406 | XOR Cost: 0.6931471805599453
# Epoch 8500 - AND Cost: 0.0017223294960300492 | OR Cost: 0.0009104808127922838 | XOR Cost: 0.6931471805599453
# Epoch 8600 - AND Cost: 0.0017102286265335644 | OR Cost: 0.000904087725061341 | XOR Cost: 0.6931471805599453
# Epoch 8700 - AND Cost: 0.0016982964180606193 | OR Cost: 0.0008977837284053156 | XOR Cost: 0.6931471805599453
# Epoch 8800 - AND Cost: 0.0016865293714475333 | OR Cost: 0.0008915669742770567 | XOR Cost: 0.6931471805599453
# Epoch 8900 - AND Cost: 0.0016749240836080128 | OR Cost: 0.0008854356649012642 | XOR Cost: 0.6931471805599453
# Epoch 9000 - AND Cost: 0.001663477244258642 | OR Cost: 0.0008793880515432093 | XOR Cost: 0.6931471805599453
# Epoch 9100 - AND Cost: 0.0016521856327791266 | OR Cost: 0.0008734224328492833 | XOR Cost: 0.6931471805599453
# Epoch 9200 - AND Cost: 0.0016410461151976465 | OR Cost: 0.0008675371532523332 | XOR Cost: 0.6931471805599453
# Epoch 9300 - AND Cost: 0.001630055641297743 | OR Cost: 0.000861730601443016 | XOR Cost: 0.6931471805599453
# Epoch 9400 - AND Cost: 0.0016192112418401113 | OR Cost: 0.0008560012089007143 | XOR Cost: 0.6931471805599453
# Epoch 9500 - AND Cost: 0.0016085100258941424 | OR Cost: 0.0008503474484829993 | XOR Cost: 0.6931471805599453
# Epoch 9600 - AND Cost: 0.0015979491782744791 | OR Cost: 0.0008447678330705435 | XOR Cost: 0.6931471805599453
# Epoch 9700 - AND Cost: 0.0015875259570772705 | OR Cost: 0.000839260914264751 | XOR Cost: 0.6931471805599453
# Epoch 9800 - AND Cost: 0.0015772376913122804 | OR Cost: 0.0008338252811361202 | XOR Cost: 0.6931471805599453
# Epoch 9900 - AND Cost: 0.001567081778625873 | OR Cost: 0.0008284595590203835 | XOR Cost: 0.6931471805599453

# %%
print("AND Prediction (0, 0):", model_AND.predict((0, 0)))
print("AND Prediction (0, 1):", model_AND.predict((0, 1)))
print("AND Prediction (1, 0):", model_AND.predict((1, 0)))
print("AND Prediction (1, 1):", model_AND.predict((1, 1)))

print("OR Prediction (0, 0):", model_OR.predict((0, 0)))
print("OR Prediction (0, 1):", model_OR.predict((0, 1)))
print("OR Prediction (1, 0):", model_OR.predict((1, 0)))
print("OR Prediction (1, 1):", model_OR.predict((1, 1)))

print("XOR Prediction (0, 0):", model_XOR.predict((0, 0)))
print("XOR Prediction (0, 1):", model_XOR.predict((0, 1)))
print("XOR Prediction (1, 0):", model_XOR.predict((1, 0)))
print("XOR Prediction (1, 1):", model_XOR.predict((1, 1)))
# Out:
# AND Prediction (0, 0): 8.631667783691301e-09
# AND Prediction (0, 1): 0.001829857502891906
# AND Prediction (1, 0): 0.0018298575028913413
# AND Prediction (1, 1): 0.9974381405511134
# OR Prediction (0, 0): 0.001828122610883802
# OR Prediction (0, 1): 0.9992688393365824
# OR Prediction (1, 0): 0.9992688425311702
# OR Prediction (1, 1): 0.9999999990194741
# XOR Prediction (0, 0): 0.5
# XOR Prediction (0, 1): 0.5
# XOR Prediction (1, 0): 0.5
# XOR Prediction (1, 1): 0.5
