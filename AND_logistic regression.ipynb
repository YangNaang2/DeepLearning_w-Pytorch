# %%
import random
from math import exp, log

# %%
X= [(0,0), (1,0), (0,1), (1,1)]
Y = [0,0,0,1]

# %%
class logistic_regression_model():
    def __init__(self):
        self.w = [random.random(), random.random()]
        self.b = random.random()
    def sigmoid(self,z):
        return 1/(1 + exp(-z))
    def predict(self,x):
        z = self.w[0] * x[0] + self.w[1] * x[1] + self.b
        a = self.sigmoid(z)
        return a

# %%
model = logistic_regression_model()

# %%
def train(X, Y, model, lr = 0.1):
    dw0 = 0.0
    dw1 = 0.0
    db = 0.0
    m = len(X)
    cost = 0.0
    for x,y in zip(X,Y):
        a = model.predict(x)
        if y == 1:
            cost -= log(a)
        else:
            cost -= log(1-a)
        dw0 += (a-y)*x[0]
        dw1 += (a-y)*x[1]
        db += (a-y)
    cost /= m
    model.w[0] -= lr * dw0/m
    model.w[1] -= lr * dw1/m
    model.b -= lr*db/m

    return cost

# %%
for epoch in range(10000):
    cost = train(X,Y, model, 0.1)
    if epoch % 100 == 0:
        print(epoch, cost)
# Out:
# 0 0.8629546908748585
# 100 0.4355165225940706
# 200 0.346535552313891
# 300 0.2903865861242532
# 400 0.2511407442312563
# 500 0.22179708361318012
# 600 0.19883120567373896
# 700 0.1802659595503311
# 800 0.1648944296058375
# 900 0.15193032659251926
# 1000 0.14083485246652555
# 1100 0.1312238203228356
# 1200 0.1228144222357858
# 1300 0.11539300412034434
# 1400 0.10879464820812401
# 1500 0.10288973272086266
# 1600 0.09757479375316885
# 1700 0.09276613849254614
# 1800 0.0883952741936685
# 1900 0.08440556863494271
# 2000 0.08074976595434197
# 2100 0.07738810921726026
# 2200 0.07428690140544666
# 2300 0.07141738847918813
# 2400 0.06875488256219563
# 2500 0.06627806654614532
# 2600 0.0639684374208041
# 2700 0.06180985684849466
# 2800 0.059788185477122766
# 2900 0.05789098323902468
# 3000 0.05610726208647189
# 3100 0.05442728072255648
# 3200 0.05284237320908184
# 3300 0.051344805086799755
# 3400 0.04992765197970677
# 3500 0.048584696682318004
# 3600 0.0473103415247819
# 3700 0.0460995334321328
# 3800 0.04494769958258015
# 3900 0.043850691956467555
# 4000 0.042804739375550516
# 4100 0.041806405879010494
# 4200 0.040852554481425454
# 4300 0.039940315518926815
# 4400 0.03906705892081959
# 4500 0.03823036985112123
# 4600 0.03742802725251409
# 4700 0.036657984897853324
# 4800 0.035918354614548724
# 4900 0.035207391397191375
# 5000 0.03452348016558249
# 5100 0.033865123960329126
# 5200 0.0332309333976045
# 5300 0.032619617229500006
# 5400 0.0320299738774014
# 5500 0.0314608838236569
# 5600 0.030911302761982774
# 5700 0.030380255420011833
# 5800 0.029866829978484798
# 5900 0.029370173021104944
# 6000 0.02888948495727043
# 6100 0.028424015866965163
# 6200 0.027973061723200757
# 6300 0.027535960952698633
# 6400 0.027112091300098274
# 6500 0.026700866964985533
# 6600 0.026301735984524895
# 6700 0.025914177837531714
# 6800 0.02553770124849621
# 6900 0.025171842172414208
# 7000 0.024816161943342203
# 7100 0.024470245571411482
# 7200 0.02413370017463599
# 7300 0.023806153533264533
# 7400 0.02348725275568271
# 7500 0.023176663045977076
# 7600 0.022874066564266063
# 7700 0.022579161371772134
# 7800 0.02229166045339804
# 7900 0.022011290811261814
# 8000 0.0217377926232704
# 8100 0.021470918461366714
# 8200 0.021210432564585505
# 8300 0.020956110162498747
# 8400 0.02070773684503322
# 8500 0.020465107975005746
# 8600 0.02022802814004346
# 8700 0.019996310640851993
# 8800 0.019769777013057894
# 8900 0.019548256580089622
# 9000 0.01933158603477904
# 9100 0.019119609047558578
# 9200 0.01891217589930893
# 9300 0.018709143137070568
# 9400 0.018510373250980577
# 9500 0.01831573437092609
# 9600 0.018125099981530522
# 9700 0.01793834865419472
# 9800 0.017755363795017298
# 9900 0.017576033407510926

# %%
model.predict((0,0))
# Out:
# 1.2415696538167963e-05

# %%
model.predict((0,1))
# Out:
# 0.02022149168896939

# %%
model.predict((1,0))
# Out:
# 0.02022148217202821

# %%
model.predict((1,1))
# Out:
# 0.971677709748898
